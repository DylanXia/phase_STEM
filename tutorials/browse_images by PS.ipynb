# %%
import phase_STEM as ps
import numpy as np
import matplotlib.pyplot as plt
# Out:
# C:\ProgramData\Miniconda3\envs\image_registration\Lib\site-packages\paramiko\pkey.py:100: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "cipher": algorithms.TripleDES,
# C:\ProgramData\Miniconda3\envs\image_registration\Lib\site-packages\paramiko\transport.py:259: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from this module in 48.0.0.
#   "class": algorithms.TripleDES,

# %%
#give a dirctory of a folder in your computer
path = "C:/Users/yuxi8598/Documents/Data_SU/Y Xia/20250310/SU102section_Co2+/"

# %%
files = ps.io.find_files(path, 'emd')
files
# Out:
# ['C:/Users/1423 1.30 Mx HAADF-DF4.emd',
#  'C:/Users/1425 660 kx HAADF-DF4.emd',
#  'C:/Users/1426 1.30 Mx HAADF-DF4.emd',
#  'C:/Users/1441 1.30 Mx HAADF-DF4.emd',
#  'C:/Users/1445 1.30 Mx HAADF-DF4.emd',
#  'C:/Users/1448 1.30 Mx HAADF-DF4.emd',
#  'C:/Users/1450 1.30 Mx HAADF-DF4.emd',
#  'C:/Users/1452 230 kx HAADF.emd',
#  'C:/Users/1522 1.30 Mx HAADF-DF4.emd',
#  'C:/Users/1533 1.30 Mx HAADF-DF4.emd',
#  'C:/Users/1534 1.30 Mx HAADF-DF4.emd',
#  'C:/Users/1536 660 kx HAADF-DF4.emd',
#  'C:/Users/1548 930 kx DF4.emd',
#  'C:/Users/1602 930 kx HAADF-DF4.emd',
#  'C:/Users/1608 330 kx HAADF-DF4.emd',
#  'C:/Users/1609 1.30 Mx HAADF-DF4.emd',
#  'C:/Users/1611 1.30 Mx HAADF-DF4.emd',
#  'C:/Users/1613 230 kx HAADF.emd']

# %%
processor = ps.tools.ImageProcessor(files[0])
processor.plot_images(colormap='viridis', saving=None)
#processor.save_to_h5(saving=os.path.splitext(files[0])[0])
